# %% [markdown]
# Load libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pystan

# %% [markdown]
# Load the synthetic data we generated previously

# %%
dat  = np.loadtxt('../data/data_npz_synthetic_fish.csv', delimiter=',')

tobs = dat[:,0]
obs  = dat[:,[1,2,3,4]]

# %% [markdown]
# In the code below we introduce a new `generated quantities` block in order to make predictions for new time points.
# Here we will solve the ODE much like before, but instead of having Stan return the solution at the observed time points, we ask Stan to return solutions at new time points of our choosing.
# To do so, we need to pass Stan two more quantities in the `data` block: the number of predictions we are asking for, denoted `npred` and the specific time `tpred`.

# %%
stan_code_pred = '''
functions {                 
   real[] npzf(real   t,     // time
              real[] x,     // state
              real[] theta, // parameters
              real[] x_r,   // fixed real data (empty)
              int[]  x_i) { // fixed integer data (empty)
   
    /*
    guide to theta:
    theta[1]:  vmax         maximum growth rate in Michaelis Menten formulation
    theta[2]:  nuthalfsat   nutrient half saturation in Michaelis Menten formulation
    theta[3]:  graz         zooplankton grazing rate
    theta[4]:  mort_p       phytoplankton mortality rate
    theta[5]:  mort_z       zooplankton mortality rate
    theta[6]:  irr          light amplitude
    theta[7]:  beta         proportionality between growth rate and zooplankton abundance
    theta[8]:  mort_f       fish mortality rate
    */

    real n = fmax(0.0, x[1]); // this ensures our variables never go negative
    real p = fmax(0.0, x[2]);
    real z = fmax(0.0, x[3]);
    real f = fmax(0.0, x[4]);

    real light   = 1.0 + 0.5*(theta[6]*sin(pi()*((t-81.25)/182.5))-theta[6]); // light limitation factor
    real growth  = theta[1]*n/(theta[2]+n) * light * p;                       // phytoplankton growth term
    real grazing = theta[3]*p*z;                                              // zooplankton consumption term
    real ploss   = theta[4]*p;                                                // phytoplankton mortality term
    real zloss   = theta[5]*z*z;                                              // zooplankton mortality term
    real fgrowth = theta[7]*z;                                                // fish growth proportional to zooplankton
    real floss   = theta[8]*f;                                                // linear fish mortality
    
    return {-growth+ploss+zloss,  // rate of change for n
            growth-grazing-ploss, // rate of change for p
            grazing-zloss,        // rate of change for z
            fgrowth - floss};     // rate of change for f
  }
}
data {
    int<lower=0> nobs;               // number of timesteps with observations
    real tobs[nobs];                 // obs times
    int<lower=0> nobsvar;            // number of observed variables
    int<lower=0> iobsvar[nobsvar];   // index of observed variable (N=0, P=1, Z=2)
    real<lower=0> obs[nobs,4];       // observed variable at measurement times
    int<lower=0> npred;              // number of points where we want predictions
    real tpred[npred];               // time points where we want predictions
}
parameters {
    real<lower=0> vmax;
    real<lower=0> nuthalfsat;
    real<lower=0> graz;
    real<lower=0> mort_p;
    real<lower=0> mort_z;
    real<lower=0,upper=1> irr;
    real<lower=0> beta;
    real<lower=0> mort_f;
    real<lower=0> x0[4];            // initial conditions
    real<lower=0> sigma[nobsvar];   // observation error (one for each observed variable)
}
transformed parameters {
    real x[nobs, 4];
    { 
        real theta[8] = {vmax,nuthalfsat,graz,mort_p,mort_z,irr,beta,mort_f};
        x = integrate_ode_rk45(npzf, x0, 0, tobs, theta,
                               rep_array(0.0, 0), rep_array(0, 0),
                               1e-5, 1e-4, 1e4);
    }
}
model {
    vmax       ~ normal(0.1, 0.1);    // prior on vmax
    nuthalfsat ~ uniform(0.0, 1.0);   // prior on nuthalfsat
    graz       ~ normal(0.01, 0.01);  // prior on graz
    mort_p     ~ normal(0.01, 0.01);  // prior on mort_p
    mort_z     ~ normal(0.01, 0.01);  // prior on mort_z
    irr        ~ uniform(0.0, 1.0);   // prior on irr
    beta       ~ normal(0.02,0.02);   // prior on proportionality
    mort_f     ~ normal(0.1,0.1);     // prior on fish mortality rate
    x0[1:4]    ~ normal(0.1, 1.0);    // prior on all three initial conditions
    for (iobs in 1:nobs){
        obs[iobs,iobsvar] ~ normal(x[iobs,iobsvar], sigma);   // likelihood of the observations
    }
}
generated quantities{
    real x_pred[npred,4];
    {real theta[8] = {vmax,nuthalfsat,graz,mort_p,mort_z,irr,beta,mort_f};
    x_pred = integrate_ode_rk45(npzf,x0,0,tpred,theta,rep_array(0.0,0),rep_array(0,0),1e-5,1e-4,1e4);
    }
}
'''

# %% [markdown]
# Set which variables we are using to estimate the parameters and initial conditions

# %%
iobsvar = np.array([0,1,2,3])

# %% [markdown]
# Below we define the times when we want to predict and count the number of predictions

# %%
tpred = np.linspace(1.0, 365*3, 365)
npred = len(tpred)

# %% [markdown]
# We add these additional pieces of information to our data object

# %%
# convert from Python's 0-based indexing to Stan's 1-based
data   = {'nobs':len(tobs),  'tobs':tobs,  'nobsvar':len(iobsvar), 'iobsvar':iobsvar+1, 'obs':obs,  'tpred':tpred, 'npred':npred}

# %%
model = pystan.StanModel(model_code=stan_code_pred, model_name='NPZF', obfuscate_model_name=False)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL NPZF NOW.

# %%
mcmc = model.sampling(data=data, iter=2000, chains=4)
print('\n'.join(x for x in mcmc.__str__().split('\n') if 'x_pred' not in x))
#print(mcmc)
# Out:
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# WARNING:pystan:214 of 4000 iterations ended with a divergence (5.35 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Inference for Stan model: NPZF.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#                 mean se_mean      sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# vmax            0.08  2.9e-4    0.01   0.06   0.07   0.08   0.08    0.1   1209    1.0
# nuthalfsat      0.49  6.0e-3    0.17   0.21   0.37   0.48   0.61   0.85    788   1.01
# graz            0.02  6.3e-5  2.6e-3   0.02   0.02   0.02   0.02   0.03   1729    1.0
# mort_p          0.01  1.6e-4  3.6e-3 9.0e-3   0.01   0.01   0.02   0.02    497    1.0
# mort_z          0.03  9.9e-5  4.1e-3   0.02   0.03   0.03   0.03   0.04   1755    1.0
# irr             0.92  3.1e-3    0.07   0.73   0.88   0.94   0.97    1.0    528    1.0
# beta            0.05  3.5e-4    0.02   0.02   0.04   0.04   0.06   0.08   1849    1.0
# mort_f          0.13  9.8e-4    0.04   0.05    0.1   0.12   0.15   0.22   1948    1.0
# x0[1]           0.61  4.1e-4    0.02   0.58    0.6   0.61   0.63   0.65   2093    1.0
# x0[2]           0.14  2.0e-4    0.01   0.12   0.14   0.14   0.15   0.17   3383    1.0
# x0[3]           0.25  4.2e-4    0.02   0.21   0.23   0.25   0.26   0.28   1888    1.0
# x0[4]           0.27  4.4e-3     0.2   0.03   0.14   0.22   0.34   0.79   2010    1.0
# sigma[1]        0.03  1.1e-4  5.7e-3   0.02   0.02   0.03   0.03   0.04   2643    1.0
# sigma[2]        0.03  1.2e-4  6.4e-3   0.02   0.03   0.03   0.04   0.05   2775    1.0
# sigma[3]        0.03  1.3e-4  6.0e-3   0.02   0.03   0.03   0.04   0.05   2281    1.0
# sigma[4]        0.03  1.2e-4  5.7e-3   0.02   0.03   0.03   0.03   0.04   2268    1.0
# x[1,1]          0.65  3.3e-4    0.02   0.62   0.64   0.65   0.66   0.68   2234    1.0
# x[2,1]          0.67  2.8e-4    0.01   0.64   0.66   0.67   0.68    0.7   2413    1.0
# x[3,1]          0.74  1.5e-4  9.2e-3   0.72   0.73   0.74   0.74   0.75   3639    1.0
# x[4,1]          0.74  1.5e-4  9.0e-3   0.72   0.73   0.74   0.74   0.75   3819    1.0
# x[5,1]           0.7  1.6e-4    0.01   0.68    0.7    0.7   0.71   0.72   3791    1.0
# x[6,1]          0.68  2.0e-4    0.01   0.65   0.67   0.68   0.68    0.7   3492    1.0
# x[7,1]          0.64  2.6e-4    0.01   0.61   0.63   0.64   0.65   0.66   2936    1.0
# x[8,1]          0.17  2.8e-4    0.02   0.14   0.16   0.17   0.18   0.21   3043    1.0
# x[9,1]          0.18  1.8e-4    0.01   0.16   0.18   0.18   0.19    0.2   3263    1.0
# x[10,1]         0.56  1.6e-4 10.0e-3   0.54   0.55   0.56   0.57   0.58   4057    1.0
# x[11,1]         0.66  1.6e-4  9.9e-3   0.64   0.65   0.66   0.66   0.68   3944    1.0
# x[12,1]         0.68  1.6e-4  9.9e-3   0.66   0.67   0.68   0.69    0.7   3837    1.0
# x[13,1]         0.72  1.7e-4    0.01    0.7   0.72   0.72   0.73   0.74   3569    1.0
# x[14,1]         0.73  1.7e-4    0.01   0.71   0.72   0.73   0.73   0.75   3526    1.0
# x[15,1]         0.37  3.8e-4    0.02   0.32   0.35   0.37   0.38   0.41   3093    1.0
# x[16,1]         0.16  2.5e-4    0.01   0.13   0.15   0.16   0.17   0.18   2582    1.0
# x[17,1]         0.18  1.8e-4    0.01   0.16   0.17   0.18   0.18    0.2   3140    1.0
# x[18,1]         0.25  1.7e-4    0.01   0.23   0.24   0.25   0.26   0.27   3379    1.0
# x[19,1]          0.5  1.5e-4  9.2e-3   0.48    0.5    0.5   0.51   0.52   3915    1.0
# x[20,1]         0.54  1.4e-4  9.1e-3   0.53   0.54   0.54   0.55   0.56   4073    1.0
# x[1,2]          0.12  1.8e-4    0.01    0.1   0.12   0.12   0.13   0.14   3414    1.0
# x[2,2]          0.11  1.6e-4  9.3e-3   0.09    0.1   0.11   0.12   0.13   3379    1.0
# x[3,2]          0.09  1.4e-4  8.0e-3   0.07   0.08   0.09   0.09    0.1   3294    1.0
# x[4,2]          0.09  1.4e-4  8.3e-3   0.08   0.09   0.09    0.1   0.11   3373    1.0
# x[5,2]          0.14  1.8e-4    0.01   0.12   0.13   0.14   0.15   0.16   3692    1.0
# x[6,2]          0.17  2.1e-4    0.01   0.15   0.16   0.17   0.18    0.2   3637    1.0
# x[7,2]          0.21  2.5e-4    0.01   0.18    0.2   0.21   0.22   0.24   3423    1.0
# x[8,2]          0.62  2.7e-4    0.01    0.6   0.62   0.63   0.63   0.65   2702    1.0
# x[9,2]          0.55  2.3e-4    0.01   0.53   0.54   0.55   0.56   0.58   3317    1.0
# x[10,2]         0.19  1.7e-4    0.01   0.17   0.18   0.19    0.2   0.21   4294    1.0
# x[11,2]         0.13  1.7e-4  9.9e-3   0.11   0.12   0.13   0.13   0.14   3538    1.0
# x[12,2]         0.11  1.7e-4  9.6e-3   0.09   0.11   0.11   0.12   0.13   3330    1.0
# x[13,2]         0.09  1.7e-4  9.4e-3   0.07   0.09   0.09    0.1   0.11   2990    1.0
# x[14,2]         0.09  1.8e-4  9.5e-3   0.07   0.09   0.09    0.1   0.11   2933    1.0
# x[15,2]         0.47  3.4e-4    0.02   0.43   0.45   0.47   0.48   0.51   3434    1.0
# x[16,2]         0.63  2.5e-4    0.01    0.6   0.62   0.63   0.64   0.65   2616    1.0
# x[17,2]         0.56  2.3e-4    0.01   0.54   0.55   0.56   0.57   0.59   3315    1.0
# x[18,2]         0.47  2.4e-4    0.01   0.44   0.46   0.47   0.48    0.5   3170    1.0
# x[19,2]         0.24  1.6e-4    0.01   0.22   0.23   0.24   0.25   0.26   4303    1.0
# x[20,2]         0.21  1.6e-4    0.01   0.18    0.2   0.21   0.21   0.22   4314    1.0
# x[1,3]          0.23  3.5e-4    0.02    0.2   0.22   0.23   0.24   0.27   2031    1.0
# x[2,3]          0.22  2.9e-4    0.01    0.2   0.21   0.22   0.23   0.25   2174    1.0
# x[3,3]          0.18  1.7e-4  9.0e-3   0.16   0.18   0.18   0.19    0.2   2901    1.0
# x[4,3]          0.18  1.6e-4  8.7e-3   0.16   0.17   0.18   0.18   0.19   2914    1.0
# x[5,3]          0.16  1.5e-4  7.9e-3   0.15   0.16   0.16   0.17   0.18   2842    1.0
# x[6,3]          0.16  1.5e-4  7.7e-3   0.14   0.15   0.16   0.16   0.18   2830    1.0
# x[7,3]          0.16  1.4e-4  7.6e-3   0.14   0.15   0.16   0.16   0.17   2843    1.0
# x[8,3]          0.21  1.4e-4  8.5e-3   0.19    0.2   0.21   0.21   0.22   3599    1.0
# x[9,3]          0.27  2.6e-4    0.01   0.24   0.26   0.27   0.28   0.29   2363    1.0
# x[10,3]         0.25  1.4e-4  8.9e-3   0.23   0.25   0.25   0.26   0.27   4075    1.0
# x[11,3]         0.22  1.5e-4  8.7e-3   0.21   0.22   0.22   0.23   0.24   3349    1.0
# x[12,3]         0.21  1.6e-4  8.8e-3    0.2   0.21   0.21   0.22   0.23   3093    1.0
# x[13,3]         0.19  1.8e-4  8.9e-3   0.17   0.18   0.19    0.2   0.21   2587    1.0
# x[14,3]         0.18  1.8e-4  9.0e-3   0.17   0.18   0.18   0.19    0.2   2489    1.0
# x[15,3]         0.17  1.4e-4  7.8e-3   0.16   0.17   0.17   0.18   0.19   3058    1.0
# x[16,3]         0.22  1.6e-4  9.0e-3    0.2   0.21   0.22   0.22   0.24   3353    1.0
# x[17,3]         0.27  2.4e-4    0.01   0.24   0.26   0.27   0.27   0.29   2553    1.0
# x[18,3]         0.29  2.4e-4    0.01   0.26   0.28   0.29   0.29   0.31   2653    1.0
# x[19,3]         0.27  1.4e-4  9.3e-3   0.25   0.26   0.27   0.27   0.28   4152    1.0
# x[20,3]         0.26  1.4e-4  9.0e-3   0.24   0.25   0.26   0.26   0.27   4164    1.0
# x[1,4]          0.12  6.1e-4    0.03   0.07    0.1   0.12   0.14   0.18   2215    1.0
# x[2,4]          0.09  2.4e-4    0.01   0.07   0.09   0.09    0.1   0.12   2469    1.0
# x[3,4]          0.07  1.3e-4  7.3e-3   0.05   0.06   0.07   0.07   0.08   3272    1.0
# x[4,4]          0.07  1.2e-4  7.0e-3   0.05   0.06   0.07   0.07   0.08   3317    1.0
# x[5,4]          0.06  1.1e-4  6.2e-3   0.05   0.06   0.06   0.06   0.07   3355    1.0
# x[6,4]          0.06  1.0e-4  6.0e-3   0.05   0.05   0.06   0.06   0.07   3368    1.0
# x[7,4]          0.06  1.0e-4  5.9e-3   0.05   0.05   0.06   0.06   0.07   3388    1.0
# x[8,4]          0.07  1.2e-4  6.6e-3   0.06   0.07   0.07   0.07   0.08   3106    1.0
# x[9,4]          0.09  1.7e-4  9.0e-3   0.08   0.09   0.09    0.1   0.11   2887    1.0
# x[10,4]         0.09  1.5e-4  9.0e-3   0.08   0.09   0.09    0.1   0.11   3659    1.0
# x[11,4]         0.08  1.4e-4  8.2e-3   0.07   0.08   0.08   0.09    0.1   3460    1.0
# x[12,4]         0.08  1.4e-4  8.0e-3   0.07   0.08   0.08   0.09    0.1   3360    1.0
# x[13,4]         0.07  1.3e-4  7.2e-3   0.06   0.07   0.07   0.08   0.09   3139    1.0
# x[14,4]         0.07  1.3e-4  7.0e-3   0.06   0.06   0.07   0.07   0.08   3085    1.0
# x[15,4]         0.06  1.0e-4  5.8e-3   0.05   0.06   0.06   0.06   0.07   3156    1.0
# x[16,4]         0.07  1.3e-4  6.9e-3   0.06   0.07   0.07   0.08   0.09   2886    1.0
# x[17,4]         0.09  1.7e-4  8.9e-3   0.08   0.09   0.09    0.1   0.11   2835    1.0
# x[18,4]          0.1  1.7e-4  9.7e-3   0.08   0.09    0.1   0.11   0.12   3138    1.0
# x[19,4]          0.1  1.5e-4  9.3e-3   0.08   0.09    0.1    0.1   0.12   3677    1.0
# x[20,4]          0.1  1.5e-4  9.1e-3   0.08   0.09    0.1    0.1   0.11   3664    1.0
# lp__          192.76     0.1    3.26 185.21 190.77  193.2 195.11  198.0   1105   1.01
#
# Samples were drawn using NUTS at Thu Jan 30 08:12:22 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
colors = ('#1f77b4','#2ca02c','#d62728','darkviolet') # colors for N, P, Z

fig,ax = plt.subplots(figsize=(12,9))
for i,name in enumerate(('N','P','Z','F')):
    label = name
    # plot only the first few samples
    for isample in range(20):
        ax.plot(tpred,mcmc['x_pred'][isample,:,i], color=colors[i], alpha=0.5, label=label)
        label = None
ax.axvline(365, color='0.7', zorder=0)
ax.set(title='NPZF model posterior samples', xlabel='time (days)')
ax.legend()
None

# %%
fig,ax = plt.subplots(figsize=(12,9))
io = 0
for i,name in enumerate(('N','P','Z','F')):
    q = np.percentile(mcmc['x_pred'][:,:,i], q=(5,25,50,75,95), axis=0)
    label = None
    if i == 2:
        label = '5%-95%ile'
    ax.fill_between(tpred, q[0,:], q[-1,:], color=colors[i], alpha=0.25, label=label)
    if i == 2:
        label = '25%-75%ile'
    ax.fill_between(tpred, q[1,:], q[-2,:], color=colors[i], alpha=0.5, label=label)
    if i == 2:
        label = name + ' median'
    else:
        label = name
    ax.plot(tpred, q[2,:], color=colors[i], linewidth=3, label=label)
    if i in iobsvar:
        ax.errorbar(tobs, obs[:,i], yerr=np.mean(mcmc['sigma'][:,io]), color=colors[i], marker='o', linestyle='none')
        io += 1
ax.axvline(365, color='0.7', zorder=0)
ax.set(title='NPZF model posterior qunatiles', xlabel='time (days)')
ax.legend()
None

# %%
iobsvar2 = np.array([0,1,2])

# %%
# convert from Python's 0-based indexing to Stan's 1-based
data2 = {'nobs':len(tobs), 'tobs':tobs, 'nobsvar':len(iobsvar2), 'iobsvar':iobsvar2+1, 'obs':obs, 'tpred':tpred, 'npred':npred}

# %%
mcmc2 = model.sampling(data=data2, iter=2000, chains=4)
# Out:
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# WARNING:pystan:222 of 4000 iterations ended with a divergence (5.55 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
fig,ax = plt.subplots(figsize=(12,9))
io = 0
for i,name in enumerate(('N','P','Z','F')):
    q = np.percentile(mcmc2['x_pred'][:,:,i], q=(5,25,50,75,95), axis=0)
    label = None
    if i == 2:
        label = '5%-95%ile'
    ax.fill_between(tpred, q[0,:], q[-1,:], color=colors[i], alpha=0.25, label=label)
    if i == 2:
        label = '25%-75%ile'
    ax.fill_between(tpred, q[1,:], q[-2,:], color=colors[i], alpha=0.5, label=label)
    if i == 2:
        label = name + ' median'
    else:
        label = name
    ax.plot(tpred, q[2,:], color=colors[i], linewidth=3, label=label)
    if i in iobsvar2:
        ax.errorbar(tobs, obs[:,i], yerr=np.mean(mcmc2['sigma'][:,io]), color=colors[i], marker='o', linestyle='none')
        io += 1
ax.axvline(365, color='0.7', zorder=0)
ax.set(title='NPZF model posterior qunatiles', xlabel='time (days)')
plt.ylim(0, 0.8)
None
